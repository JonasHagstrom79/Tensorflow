# %% [markdown]
# # Introduction to Convolutional Neural Networks and Computer Vision with Tesnorflow
#
# Computer vision is the practice of writing algorithms wich can discover patterns in visual data. Such as the camera of self-driving car recognizing the car in front.
#
# ![2022-07-29 (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Get the data
#
# The images we're working wth are from the [Food101 dataset](https://www.kaggle.com/datasets/dansbecker/food-101) (101 different classes of food)
# It's modified to only use two classes (pizza 🍕 and steak 🍖) using the [image_data_modification](https://github.com/mrdbourke/tensorflow-deep-learning/blob/main/extras/image_data_modification.ipynb) notebook.

# %%
import zipfile

# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip

# Unzip the downloaded file
zip_ref = zipfile.ZipFile("pizza_steak.zip")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2022-08-04 14:44:00--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.128, 74.125.142.128, 74.125.195.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109540975 (104M) [application/zip]
# Saving to: ‘pizza_steak.zip.1’
#
# pizza_steak.zip.1   100%[===================>] 104.47M   178MB/s    in 0.6s
#
# 2022-08-04 14:44:01 (178 MB/s) - ‘pizza_steak.zip.1’ saved [109540975/109540975]

# %% [markdown]
# ## Inspect the data (become one with it)
#
# A very crucial step at the beginning of any machine learning project is becoming one with the data.
#
# And for a computer vision project.. this usually means visualizing many samples of your data.

# %%
# !ls pizza_steak # ls stands for list
# Out:
# test  train

# %%
# !ls pizza_steak/train/
# Out:
# pizza  steak

# %%
# !ls pizza_steak/train/steak
# Out:
# 1000205.jpg  1647351.jpg  2238681.jpg  2824680.jpg  3375959.jpg  417368.jpg
# 100135.jpg   1650002.jpg  2238802.jpg  2825100.jpg  3381560.jpg  4176.jpg
# 101312.jpg   165639.jpg   2254705.jpg  2826987.jpg  3382936.jpg  42125.jpg
# 1021458.jpg  1658186.jpg  225990.jpg   2832499.jpg  3386119.jpg  421476.jpg
# 1032846.jpg  1658443.jpg  2260231.jpg  2832960.jpg  3388717.jpg  421561.jpg
# 10380.jpg    165964.jpg   2268692.jpg  285045.jpg   3389138.jpg  438871.jpg
# 1049459.jpg  167069.jpg   2271133.jpg  285147.jpg   3393547.jpg  43924.jpg
# 1053665.jpg  1675632.jpg  227576.jpg   2855315.jpg  3393688.jpg  440188.jpg
# 1068516.jpg  1678108.jpg  2283057.jpg  2856066.jpg  3396589.jpg  442757.jpg
# 1068975.jpg  168006.jpg   2286639.jpg  2859933.jpg  339891.jpg	 443210.jpg
# 1081258.jpg  1682496.jpg  2287136.jpg  286219.jpg   3417789.jpg  444064.jpg
# 1090122.jpg  1684438.jpg  2291292.jpg  2862562.jpg  3425047.jpg  444709.jpg
# 1093966.jpg  168775.jpg   229323.jpg   2865730.jpg  3434983.jpg  447557.jpg
# 1098844.jpg  1697339.jpg  2300534.jpg  2878151.jpg  3435358.jpg  461187.jpg
# 1100074.jpg  1710569.jpg  2300845.jpg  2880035.jpg  3438319.jpg  461689.jpg
# 1600179.jpg  2159975.jpg  2748917.jpg  331860.jpg   3894222.jpg  931356.jpg
# 1600794.jpg  2163079.jpg  2760475.jpg  332232.jpg   3895825.jpg  937133.jpg
# 160552.jpg   217250.jpg   2761427.jpg  3322909.jpg  389739.jpg	 945791.jpg
# 1606596.jpg  2172600.jpg  2765887.jpg  332557.jpg   3916407.jpg  947877.jpg
# 1615395.jpg  2173084.jpg  2768451.jpg  3326734.jpg  393349.jpg	 952407.jpg
# 1618011.jpg  217996.jpg   2771149.jpg  3330642.jpg  393494.jpg	 952437.jpg
# 1619357.jpg  2193684.jpg  2779040.jpg  3333128.jpg  398288.jpg	 955466.jpg
# 1621763.jpg  220341.jpg   2788312.jpg  3333735.jpg  40094.jpg	 9555.jpg
# 1623325.jpg  22080.jpg	  2788759.jpg  3334973.jpg  401094.jpg	 961341.jpg
# 1624450.jpg  2216146.jpg  2796102.jpg  3335013.jpg  401144.jpg	 97656.jpg
# 1624747.jpg  2222018.jpg  280284.jpg   3335267.jpg  401651.jpg	 979110.jpg
# 1628861.jpg  2223787.jpg  2807888.jpg  3346787.jpg  405173.jpg	 980247.jpg
# 1632774.jpg  2230959.jpg  2815172.jpg  3364420.jpg  405794.jpg	 982988.jpg
# 1636831.jpg  2232310.jpg  2818805.jpg  336637.jpg   40762.jpg	 987732.jpg
# 1645470.jpg  2233395.jpg  2823872.jpg  3372616.jpg  413325.jpg	 996684.jpg

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("pizza_steak"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in 'pizza_steak'.
# There are 2 directories and 0 images in 'pizza_steak/test'.
# There are 0 directories and 250 images in 'pizza_steak/test/pizza'.
# There are 0 directories and 250 images in 'pizza_steak/test/steak'.
# There are 2 directories and 0 images in 'pizza_steak/train'.
# There are 0 directories and 750 images in 'pizza_steak/train/pizza'.
# There are 0 directories and 750 images in 'pizza_steak/train/steak'.

# %%
# Anoter way to find out how many images are in a file
num_steak_images_train = len(os.listdir("pizza_steak/train/steak"))

num_steak_images_train
# Out:
# 750

# %% [markdown]
# To visualize our images, first let's get the class names programmaticallt.

# %%
# Get the classnames programmatically
import pathlib
import numpy as np
data_dir = pathlib.Path("pizza_steak/train")
class_names = np.array(sorted((item.name for item in data_dir.glob("*")))) # Created a list of class_names from the subdirectory
# class_names = class_names[1:] # Remove .DS_store
print(class_names) # [1:] = one onwards
# Out:
# ['pizza' 'steak']

# %%
# Let's visualize our images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup the target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)
  print(random_image)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  # Print the shape, this is important in ML
  print(f"Image shape: {img.shape}") # Show the shape of the image

  return img

# %%
# View a random image from the dataset
img = view_random_image(target_dir="pizza_steak/train/",
                        target_class="steak")
# Out:
# ['1049459.jpg']
# Image shape: (512, 512, 3)

# %%
img
# Out:
# array([[[  2,   4,   1],
#         [  2,   4,   1],
#         [  2,   4,   1],
#         ...,
#         [ 23,  14,  19],
#         [ 22,  13,  18],
#         [ 23,  14,  19]],
#
#        [[  2,   4,   1],
#         [  2,   4,   1],
#         [  2,   4,   1],
#         ...,
#         [ 23,  12,  18],
#         [ 22,  13,  18],
#         [ 23,  14,  19]],
#
#        [[  1,   3,   0],
#         [  1,   3,   0],
#         [  1,   3,   0],
#         ...,
#         [ 23,  12,  18],
#         [ 23,  12,  18],
#         [ 25,  14,  20]],
#
#        ...,
#
#        [[109,  67,  19],
#         [113,  71,  23],
#         [123,  81,  33],
#         ...,
#         [126,  72,  25],
#         [126,  72,  25],
#         [130,  76,  29]],
#
#        [[115,  75,  26],
#         [110,  70,  21],
#         [114,  74,  25],
#         ...,
#         [133,  77,  30],
#         [131,  75,  28],
#         [135,  79,  30]],
#
#        [[ 99,  58,  12],
#         [ 94,  53,   7],
#         [107,  67,  18],
#         ...,
#         [139,  83,  36],
#         [131,  75,  26],
#         [129,  73,  24]]], dtype=uint8)

# %%
# Make a tensor of the img array
import tensorflow as tf
tf.constant(img)
# Out:
# <tf.Tensor: shape=(512, 512, 3), dtype=uint8, numpy=
# array([[[  2,   4,   1],
#         [  2,   4,   1],
#         [  2,   4,   1],
#         ...,
#         [ 23,  14,  19],
#         [ 22,  13,  18],
#         [ 23,  14,  19]],
#
#        [[  2,   4,   1],
#         [  2,   4,   1],
#         [  2,   4,   1],
#         ...,
#         [ 23,  12,  18],
#         [ 22,  13,  18],
#         [ 23,  14,  19]],
#
#        [[  1,   3,   0],
#         [  1,   3,   0],
#         [  1,   3,   0],
#         ...,
#         [ 23,  12,  18],
#         [ 23,  12,  18],
#         [ 25,  14,  20]],
#
#        ...,
#
#        [[109,  67,  19],
#         [113,  71,  23],
#         [123,  81,  33],
#         ...,
#         [126,  72,  25],
#         [126,  72,  25],
#         [130,  76,  29]],
#
#        [[115,  75,  26],
#         [110,  70,  21],
#         [114,  74,  25],
#         ...,
#         [133,  77,  30],
#         [131,  75,  28],
#         [135,  79,  30]],
#
#        [[ 99,  58,  12],
#         [ 94,  53,   7],
#         [107,  67,  18],
#         ...,
#         [139,  83,  36],
#         [131,  75,  26],
#         [129,  73,  24]]], dtype=uint8)>

# %%
# View the image shape
img.shape # returns width, height, colour channels
# Out:
# (512, 512, 3)

# %% [markdown]
# ![2022-08-01 (2).png](data:image/png;base64,...)
#
# 🔑**Note:** As we've discussed before, many machine learning models, including neural networks prefer the values they work with to be between 0 and 1. Knowing this, one of the most common preprocessing steps for working with images is to **scale** (also referred to as **normalize**) their pixel values by dividing the image arrays by 255. (Since 255 is the maximum pixel value).

# %%
# Get all the numbers in the input tensor between 0 and 1, normalization or scaling
img/255. # Divide with 255, the "." at the end turns it into a float
# Out:
# array([[[0.00784314, 0.01568627, 0.00392157],
#         [0.00784314, 0.01568627, 0.00392157],
#         [0.00784314, 0.01568627, 0.00392157],
#         ...,
#         [0.09019608, 0.05490196, 0.0745098 ],
#         [0.08627451, 0.05098039, 0.07058824],
#         [0.09019608, 0.05490196, 0.0745098 ]],
#
#        [[0.00784314, 0.01568627, 0.00392157],
#         [0.00784314, 0.01568627, 0.00392157],
#         [0.00784314, 0.01568627, 0.00392157],
#         ...,
#         [0.09019608, 0.04705882, 0.07058824],
#         [0.08627451, 0.05098039, 0.07058824],
#         [0.09019608, 0.05490196, 0.0745098 ]],
#
#        [[0.00392157, 0.01176471, 0.        ],
#         [0.00392157, 0.01176471, 0.        ],
#         [0.00392157, 0.01176471, 0.        ],
#         ...,
#         [0.09019608, 0.04705882, 0.07058824],
#         [0.09019608, 0.04705882, 0.07058824],
#         [0.09803922, 0.05490196, 0.07843137]],
#
#        ...,
#
#        [[0.42745098, 0.2627451 , 0.0745098 ],
#         [0.44313725, 0.27843137, 0.09019608],
#         [0.48235294, 0.31764706, 0.12941176],
#         ...,
#         [0.49411765, 0.28235294, 0.09803922],
#         [0.49411765, 0.28235294, 0.09803922],
#         [0.50980392, 0.29803922, 0.11372549]],
#
#        [[0.45098039, 0.29411765, 0.10196078],
#         [0.43137255, 0.2745098 , 0.08235294],
#         [0.44705882, 0.29019608, 0.09803922],
#         ...,
#         [0.52156863, 0.30196078, 0.11764706],
#         [0.51372549, 0.29411765, 0.10980392],
#         [0.52941176, 0.30980392, 0.11764706]],
#
#        [[0.38823529, 0.22745098, 0.04705882],
#         [0.36862745, 0.20784314, 0.02745098],
#         [0.41960784, 0.2627451 , 0.07058824],
#         ...,
#         [0.54509804, 0.3254902 , 0.14117647],
#         [0.51372549, 0.29411765, 0.10196078],
#         [0.50588235, 0.28627451, 0.09411765]]])

# %% [markdown]
# ## An end-to-end example
#
# Let's build a convolutional neural network to find patterns in our images, more specifically we need a way to:
#
# * Load our images
# * Preprocess our images
# * Build a CNN to find patterns in our images
# * Compile our CNN
# * Fit the CNN to our training data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set the seed
tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 0 & 1, also called preprocessing/normalization)
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Setup paths to our data directories
train_dir = "/content/pizza_steak/train"
test_dir = "pizza_steak/test"

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(directory=train_dir,
                                               batch_size=32,
                                               target_size=(224, 224), # The size we want all of our images to be
                                               class_mode= "binary",
                                               seed=42)

valid_data = valid_datagen.flow_from_directory(directory=test_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)

# Build a CNN model (same as the Tiny VGG on the CNN explainer website)
model_1 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(filters=10,
                         kernel_size=3,
                         activation="relu",
                         input_shape=(224, 224, 3)),
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2,
                            padding="valid"),
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  tf.keras.layers.Conv2D(10, 3, activation="relu"),
  #tf.keras.layers.Activations(tf.nn.relu), # Another way to do it as the line above
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile our CNN
model_1.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Fit the model
history_1 = model_1.fit(train_data,
                        epochs = 5,
                        steps_per_epoch=len(train_data), # 47 steps per epoch
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Epoch 1/5
# 47/47 [==============================] - 11s 205ms/step - loss: 0.5617 - accuracy: 0.6913 - val_loss: 0.3904 - val_accuracy: 0.8260
# Epoch 2/5
# 47/47 [==============================] - 9s 195ms/step - loss: 0.4263 - accuracy: 0.8013 - val_loss: 0.3309 - val_accuracy: 0.8660
# Epoch 3/5
# 47/47 [==============================] - 9s 198ms/step - loss: 0.3768 - accuracy: 0.8373 - val_loss: 0.3275 - val_accuracy: 0.8540
# Epoch 4/5
# 47/47 [==============================] - 9s 195ms/step - loss: 0.3335 - accuracy: 0.8527 - val_loss: 0.3100 - val_accuracy: 0.8760
# Epoch 5/5
# 47/47 [==============================] - 9s 197ms/step - loss: 0.2904 - accuracy: 0.8860 - val_loss: 0.2969 - val_accuracy: 0.8700

# %% [markdown]
# 🔑 **Note:** If the above cell is taking longer than ~10 seconds per epoch, use the **GPU** to speed things up by x5

# %%
model_1.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 10)      280
#
#  conv2d_5 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d_2 (MaxPooling  (None, 110, 110, 10)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_7 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_3 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten_6 (Flatten)         (None, 28090)             0
#
#  dense_19 (Dense)            (None, 1)                 28091
#
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Using the same model as before

# %%
# Set seed
tf.random.set_seed(42)

# Build the model from TenosrFlow website
model_2 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(224, 224, 3)),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(1, activation="sigmoid")  
])

# Compile the model
model_2.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Fit the model
history_2 = model_2.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 9s 186ms/step - loss: 0.8313 - accuracy: 0.5047 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/5
# 47/47 [==============================] - 8s 181ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/5
# 47/47 [==============================] - 9s 193ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/5
# 47/47 [==============================] - 9s 191ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/5
# 47/47 [==============================] - 9s 186ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000

# %%
# Try upgrading the model above

# Set seed
tf.random.set_seed(42)

# Build the model from TenosrFlow website
model_3 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(224, 224, 3)),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1, activation="sigmoid")  
])

# Compile the model
model_3.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Fit the model
history_3 = model_3.fit(train_data,
                        epochs=100,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/100
# 47/47 [==============================] - 9s 192ms/step - loss: 4.0259 - accuracy: 0.6120 - val_loss: 1.3102 - val_accuracy: 0.5700
# Epoch 2/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.6777 - accuracy: 0.7093 - val_loss: 0.5110 - val_accuracy: 0.7660
# Epoch 3/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.6577 - accuracy: 0.7207 - val_loss: 0.5736 - val_accuracy: 0.7260
# Epoch 4/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.5438 - accuracy: 0.7713 - val_loss: 0.4534 - val_accuracy: 0.7740
# Epoch 5/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.4875 - accuracy: 0.7727 - val_loss: 0.7342 - val_accuracy: 0.6280
# Epoch 6/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.4349 - accuracy: 0.7967 - val_loss: 0.4274 - val_accuracy: 0.8020
# Epoch 7/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.4394 - accuracy: 0.8193 - val_loss: 0.4648 - val_accuracy: 0.7960
# Epoch 8/100
# 47/47 [==============================] - 9s 187ms/step - loss: 0.4586 - accuracy: 0.7993 - val_loss: 0.4217 - val_accuracy: 0.7980
# Epoch 9/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.5894 - accuracy: 0.7627 - val_loss: 0.4599 - val_accuracy: 0.7740
# Epoch 10/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.4929 - accuracy: 0.7947 - val_loss: 0.4611 - val_accuracy: 0.7940
# Epoch 11/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.4961 - accuracy: 0.7953 - val_loss: 0.5837 - val_accuracy: 0.7500
# Epoch 12/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.3988 - accuracy: 0.8360 - val_loss: 0.4519 - val_accuracy: 0.7820
# Epoch 13/100
# 47/47 [==============================] - 9s 189ms/step - loss: 0.3573 - accuracy: 0.8560 - val_loss: 0.5585 - val_accuracy: 0.7180
# Epoch 14/100
# 47/47 [==============================] - 9s 188ms/step - loss: 0.4690 - accuracy: 0.8087 - val_loss: 0.4134 - val_accuracy: 0.8120
# Epoch 15/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.3035 - accuracy: 0.8700 - val_loss: 0.4470 - val_accuracy: 0.8120
# Epoch 16/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.2665 - accuracy: 0.8993 - val_loss: 0.4134 - val_accuracy: 0.8060
# Epoch 17/100
# 47/47 [==============================] - 9s 187ms/step - loss: 0.2425 - accuracy: 0.9020 - val_loss: 0.6681 - val_accuracy: 0.7300
# Epoch 18/100
# 47/47 [==============================] - 9s 200ms/step - loss: 0.2905 - accuracy: 0.8827 - val_loss: 0.7375 - val_accuracy: 0.6940
# Epoch 19/100
# 47/47 [==============================] - 9s 187ms/step - loss: 0.3819 - accuracy: 0.8327 - val_loss: 0.4856 - val_accuracy: 0.7860
# Epoch 20/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.2141 - accuracy: 0.9093 - val_loss: 0.5289 - val_accuracy: 0.7920
# Epoch 21/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1576 - accuracy: 0.9400 - val_loss: 0.6616 - val_accuracy: 0.7760
# Epoch 22/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.1941 - accuracy: 0.9240 - val_loss: 0.6256 - val_accuracy: 0.7740
# Epoch 23/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.2834 - accuracy: 0.8893 - val_loss: 0.5350 - val_accuracy: 0.8060
# Epoch 24/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.2276 - accuracy: 0.9100 - val_loss: 0.6217 - val_accuracy: 0.7500
# Epoch 25/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1288 - accuracy: 0.9473 - val_loss: 0.4911 - val_accuracy: 0.8240
# Epoch 26/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.2781 - accuracy: 0.9047 - val_loss: 0.9449 - val_accuracy: 0.7140
# Epoch 27/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.2902 - accuracy: 0.8900 - val_loss: 0.5057 - val_accuracy: 0.8200
# Epoch 28/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.2076 - accuracy: 0.9293 - val_loss: 0.6399 - val_accuracy: 0.7900
# Epoch 29/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.1201 - accuracy: 0.9620 - val_loss: 0.6203 - val_accuracy: 0.8000
# Epoch 30/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.2117 - accuracy: 0.9147 - val_loss: 1.4198 - val_accuracy: 0.7180
# Epoch 31/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.3074 - accuracy: 0.8847 - val_loss: 0.6256 - val_accuracy: 0.7660
# Epoch 32/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.3434 - accuracy: 0.8653 - val_loss: 0.8365 - val_accuracy: 0.7440
# Epoch 33/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.2033 - accuracy: 0.9220 - val_loss: 0.8822 - val_accuracy: 0.7560
# Epoch 34/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1933 - accuracy: 0.9253 - val_loss: 0.7083 - val_accuracy: 0.7640
# Epoch 35/100
# 47/47 [==============================] - 9s 201ms/step - loss: 0.1113 - accuracy: 0.9613 - val_loss: 0.6318 - val_accuracy: 0.8060
# Epoch 36/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.3512 - accuracy: 0.8953 - val_loss: 1.2470 - val_accuracy: 0.6900
# Epoch 37/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.2916 - accuracy: 0.8913 - val_loss: 0.6170 - val_accuracy: 0.7160
# Epoch 38/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.1567 - accuracy: 0.9407 - val_loss: 0.6557 - val_accuracy: 0.7440
# Epoch 39/100
# 47/47 [==============================] - 8s 181ms/step - loss: 0.0898 - accuracy: 0.9713 - val_loss: 0.7429 - val_accuracy: 0.7740
# Epoch 40/100
# 47/47 [==============================] - 8s 181ms/step - loss: 0.0893 - accuracy: 0.9627 - val_loss: 0.8088 - val_accuracy: 0.7700
# Epoch 41/100
# 47/47 [==============================] - 8s 181ms/step - loss: 0.1394 - accuracy: 0.9467 - val_loss: 1.3353 - val_accuracy: 0.6260
# Epoch 42/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.4704 - accuracy: 0.7787 - val_loss: 0.5723 - val_accuracy: 0.6700
# Epoch 43/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.3440 - accuracy: 0.8773 - val_loss: 0.5054 - val_accuracy: 0.8020
# Epoch 44/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.2362 - accuracy: 0.9133 - val_loss: 0.5698 - val_accuracy: 0.7900
# Epoch 45/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.1838 - accuracy: 0.9340 - val_loss: 1.2030 - val_accuracy: 0.6640
# Epoch 46/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.5670 - accuracy: 0.7773 - val_loss: 0.5686 - val_accuracy: 0.7140
# Epoch 47/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.3203 - accuracy: 0.8700 - val_loss: 0.4959 - val_accuracy: 0.7780
# Epoch 48/100
# 47/47 [==============================] - 8s 181ms/step - loss: 0.3435 - accuracy: 0.8533 - val_loss: 0.4930 - val_accuracy: 0.8120
# Epoch 49/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.3510 - accuracy: 0.8580 - val_loss: 0.5105 - val_accuracy: 0.7760
# Epoch 50/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.2435 - accuracy: 0.9000 - val_loss: 0.6904 - val_accuracy: 0.7540
# Epoch 51/100
# 47/47 [==============================] - 9s 198ms/step - loss: 0.1899 - accuracy: 0.9320 - val_loss: 0.5894 - val_accuracy: 0.7400
# Epoch 52/100
# 47/47 [==============================] - 8s 180ms/step - loss: 0.2899 - accuracy: 0.8867 - val_loss: 0.5241 - val_accuracy: 0.7660
# Epoch 53/100
# 47/47 [==============================] - 8s 180ms/step - loss: 0.2719 - accuracy: 0.8947 - val_loss: 0.7688 - val_accuracy: 0.7060
# Epoch 54/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.2930 - accuracy: 0.8873 - val_loss: 0.5541 - val_accuracy: 0.7700
# Epoch 55/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.1359 - accuracy: 0.9587 - val_loss: 0.5768 - val_accuracy: 0.7900
# Epoch 56/100
# 47/47 [==============================] - 8s 181ms/step - loss: 0.2337 - accuracy: 0.9107 - val_loss: 0.5618 - val_accuracy: 0.7820
# Epoch 57/100
# 47/47 [==============================] - 8s 179ms/step - loss: 0.1757 - accuracy: 0.9353 - val_loss: 0.6329 - val_accuracy: 0.7320
# Epoch 58/100
# 47/47 [==============================] - 8s 180ms/step - loss: 0.1779 - accuracy: 0.9300 - val_loss: 0.6749 - val_accuracy: 0.7900
# Epoch 59/100
# 47/47 [==============================] - 8s 179ms/step - loss: 0.1073 - accuracy: 0.9607 - val_loss: 0.7343 - val_accuracy: 0.7860
# Epoch 60/100
# 47/47 [==============================] - 8s 180ms/step - loss: 0.1496 - accuracy: 0.9507 - val_loss: 1.8049 - val_accuracy: 0.7000
# Epoch 61/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.2723 - accuracy: 0.9020 - val_loss: 0.6860 - val_accuracy: 0.7680
# Epoch 62/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.0972 - accuracy: 0.9687 - val_loss: 0.5895 - val_accuracy: 0.7880
# Epoch 63/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0688 - accuracy: 0.9793 - val_loss: 0.7740 - val_accuracy: 0.7720
# Epoch 64/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1229 - accuracy: 0.9520 - val_loss: 0.8741 - val_accuracy: 0.7220
# Epoch 65/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1080 - accuracy: 0.9607 - val_loss: 0.9729 - val_accuracy: 0.6900
# Epoch 66/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.0569 - accuracy: 0.9847 - val_loss: 0.8729 - val_accuracy: 0.7880
# Epoch 67/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0366 - accuracy: 0.9880 - val_loss: 0.8254 - val_accuracy: 0.7760
# Epoch 68/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0322 - accuracy: 0.9907 - val_loss: 1.0075 - val_accuracy: 0.7660
# Epoch 69/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.5352 - accuracy: 0.8307 - val_loss: 0.4980 - val_accuracy: 0.7700
# Epoch 70/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.2535 - accuracy: 0.8973 - val_loss: 0.5195 - val_accuracy: 0.7880
# Epoch 71/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.2226 - accuracy: 0.9087 - val_loss: 0.5734 - val_accuracy: 0.7820
# Epoch 72/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.1338 - accuracy: 0.9533 - val_loss: 0.6281 - val_accuracy: 0.7700
# Epoch 73/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.2249 - accuracy: 0.9127 - val_loss: 0.5413 - val_accuracy: 0.7720
# Epoch 74/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.3217 - accuracy: 0.8620 - val_loss: 0.6657 - val_accuracy: 0.7720
# Epoch 75/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.1284 - accuracy: 0.9540 - val_loss: 0.6256 - val_accuracy: 0.7780
# Epoch 76/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.0904 - accuracy: 0.9693 - val_loss: 0.7230 - val_accuracy: 0.7620
# Epoch 77/100
# 47/47 [==============================] - 9s 187ms/step - loss: 0.0778 - accuracy: 0.9720 - val_loss: 0.7533 - val_accuracy: 0.7500
# Epoch 78/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.0598 - accuracy: 0.9780 - val_loss: 0.7940 - val_accuracy: 0.7740
# Epoch 79/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0880 - accuracy: 0.9740 - val_loss: 2.2063 - val_accuracy: 0.6000
# Epoch 80/100
# 47/47 [==============================] - 9s 182ms/step - loss: 0.5423 - accuracy: 0.8247 - val_loss: 0.4987 - val_accuracy: 0.7940
# Epoch 81/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.1682 - accuracy: 0.9313 - val_loss: 0.5854 - val_accuracy: 0.7860
# Epoch 82/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.0795 - accuracy: 0.9820 - val_loss: 0.7102 - val_accuracy: 0.7720
# Epoch 83/100
# 47/47 [==============================] - 9s 191ms/step - loss: 0.0898 - accuracy: 0.9713 - val_loss: 0.7622 - val_accuracy: 0.7600
# Epoch 84/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0672 - accuracy: 0.9780 - val_loss: 0.7744 - val_accuracy: 0.7760
# Epoch 85/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.1159 - accuracy: 0.9547 - val_loss: 0.7593 - val_accuracy: 0.7600
# Epoch 86/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.0316 - accuracy: 0.9940 - val_loss: 0.8220 - val_accuracy: 0.7720
# Epoch 87/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0218 - accuracy: 0.9980 - val_loss: 0.9017 - val_accuracy: 0.7700
# Epoch 88/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0181 - accuracy: 0.9960 - val_loss: 0.9118 - val_accuracy: 0.7620
# Epoch 89/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 1.0882 - val_accuracy: 0.7420
# Epoch 90/100
# 47/47 [==============================] - 9s 183ms/step - loss: 0.0195 - accuracy: 0.9960 - val_loss: 1.0289 - val_accuracy: 0.7560
# Epoch 91/100
# 47/47 [==============================] - 9s 184ms/step - loss: 0.0166 - accuracy: 0.9960 - val_loss: 1.0525 - val_accuracy: 0.7640
# Epoch 92/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.0113 - accuracy: 0.9987 - val_loss: 1.0888 - val_accuracy: 0.7700
# Epoch 93/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.0234 - accuracy: 0.9927 - val_loss: 1.8070 - val_accuracy: 0.6580
# Epoch 94/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.7733 - accuracy: 0.8033 - val_loss: 0.5911 - val_accuracy: 0.7760
# Epoch 95/100
# 47/47 [==============================] - 9s 185ms/step - loss: 0.1855 - accuracy: 0.9313 - val_loss: 0.6145 - val_accuracy: 0.7780
# Epoch 96/100
# 47/47 [==============================] - 9s 188ms/step - loss: 0.0739 - accuracy: 0.9847 - val_loss: 0.6825 - val_accuracy: 0.7760
# Epoch 97/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.0268 - accuracy: 0.9980 - val_loss: 0.8126 - val_accuracy: 0.7680
# Epoch 98/100
# 47/47 [==============================] - 9s 186ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.9383 - val_accuracy: 0.7760
# Epoch 99/100
# 47/47 [==============================] - 10s 204ms/step - loss: 0.0180 - accuracy: 0.9973 - val_loss: 1.1511 - val_accuracy: 0.7360
# Epoch 100/100
# 47/47 [==============================] - 9s 188ms/step - loss: 0.0512 - accuracy: 0.9840 - val_loss: 2.4628 - val_accuracy: 0.5920

# %%
# Get a summary of model_2
model_2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 150528)            0
#
#  dense_20 (Dense)            (None, 4)                 602116
#
#  dense_21 (Dense)            (None, 4)                 20
#
#  dense_22 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 602,141
# Trainable params: 602,141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Despite having 20x more parameters than our CNN (model_1), model_2 performs terrebly. Time to try to improve it ^^

# %%
from tensorflow.python.eager.monitoring import Metric
# Set random seed
tf.random.set_seed(42)

# Create the model
model_4 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(224,224,3)),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_4.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Fit the model
history_4 = model_4.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 9s 192ms/step - loss: 3.1753 - accuracy: 0.6200 - val_loss: 0.6180 - val_accuracy: 0.7680
# Epoch 2/5
# 47/47 [==============================] - 9s 187ms/step - loss: 1.0077 - accuracy: 0.6953 - val_loss: 0.5849 - val_accuracy: 0.7460
# Epoch 3/5
# 47/47 [==============================] - 9s 185ms/step - loss: 0.6279 - accuracy: 0.7313 - val_loss: 0.4895 - val_accuracy: 0.7580
# Epoch 4/5
# 47/47 [==============================] - 9s 188ms/step - loss: 0.5359 - accuracy: 0.7533 - val_loss: 0.7296 - val_accuracy: 0.6320
# Epoch 5/5
# 47/47 [==============================] - 10s 213ms/step - loss: 0.5498 - accuracy: 0.7473 - val_loss: 0.4678 - val_accuracy: 0.7880

# %%
# Get a summary of model_4
model_4.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 150528)            0
#
#  dense_27 (Dense)            (None, 100)               15052900
#
#  dense_28 (Dense)            (None, 100)               10100
#
#  dense_29 (Dense)            (None, 100)               10100
#
#  dense_30 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 15,073,201
# Trainable params: 15,073,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model_4 have 484 times more params than model_1 but is still outperformed by it. Power of CNN in computer vision
15000000/31000
# Out:
# 483.8709677419355

# %% [markdown]
# 🔑**Note:** You can think of trainable paraeters as **patterns a model can learn from data**. Intuitively, you might think more is better. And in lots of cases, it is. But in this case, the difference here is the two different styles of model we're using. Where a series of dense layers has a number of different learnable parameters connected to each other and hence a higher number of possible learnable patterns, **a convolutional neural network (CNN) seeks to sort out and learn the most important patterns in an image.** So even though there are less learnable paraeters in our convolutional neural network, these are often more helpful in dechipering between different **features** in an image.
# * Check out [CNN Explainer](https://poloclub.github.io/cnn-explainer/) for more reading.

# %% [markdown]
# ## Binary Classification: Let's break it down
#
# 1. Become one with the data (visualize, visualize, visualize)
# 2. Preprocess the data (prepared it for our model, the main step here was scaling/normalizing)
# 3. Create a model (start with a basline)
# 4. Fit the model
# 5. Evaluate the model
# 6. Adjust different parameters and improve the model (try to beat or baseline)
# 7. Repeat until satisfied (experiment, experiment, experiment)

# %% [markdown]
# ### 1. Become one with the data

# %%
# Visualize the data
plt.figure()
plt.subplot(1, 2, 1)
steak_img = view_random_image("pizza_steak/train/", "steak")
plt.subplot(1, 2, 2)
pizza_img = view_random_image("pizza_steak/train/", "pizza")
# Out:
# ['822550.jpg']
# Image shape: (384, 512, 3)
# ['2667824.jpg']
# Image shape: (384, 512, 3)
